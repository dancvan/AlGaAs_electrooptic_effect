# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
folder = '../../../measurements/FSS_tfs/12_14_2019b/'

# %%
in_chan = 'intest2'

# %%
#prefix = ['fastmonitor','pcmonitor']
out_chan = 'fssmixerout'
dial_adj = ['lasergain']
dial_set = ['dial3']
inj_set = ['inj700mV']
suffix = ['_amp', '_ph']
#ex_label = '_SR560_1'

# %%
## Check if file name exists

# %%
amp = [np.loadtxt(folder + out_chan   +'_' +  in_chan + '_'  + dial_adj +  suffix[0] + '.TXT') for i in inj_set]
ph = [np.loadtxt(folder + out_chan + '_' + in_chan + '_' + j +  suffix[1] +  '.TXT') for j in inj_set ]
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-11-f89d7e9d7646> in <module>
# ----> 1 amp = [np.loadtxt(folder + out_chan   +'_' +  in_chan + '_'  + i +  suffix[0] + '.TXT') for i in inj_set]
#       2 ph = [np.loadtxt(folder + out_chan + '_' + in_chan + '_' + j +  suffix[1] +  '.TXT') for j in inj_set ]
#
# <ipython-input-11-f89d7e9d7646> in <listcomp>(.0)
# ----> 1 amp = [np.loadtxt(folder + out_chan   +'_' +  in_chan + '_'  + i +  suffix[0] + '.TXT') for i in inj_set]
#       2 ph = [np.loadtxt(folder + out_chan + '_' + in_chan + '_' + j +  suffix[1] +  '.TXT') for j in inj_set ]
#
# ~/anaconda3/envs/jupy/lib/python3.7/site-packages/numpy/lib/npyio.py in loadtxt(fname, dtype, comments, delimiter, converters, skiprows, usecols, unpack, ndmin, encoding, max_rows)
#     966             fname = os_fspath(fname)
#     967         if _is_string_like(fname):
# --> 968             fh = np.lib._datasource.open(fname, 'rt', encoding=encoding)
#     969             fencoding = getattr(fh, 'encoding', 'latin1')
#     970             fh = iter(fh)
#
# ~/anaconda3/envs/jupy/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(path, mode, destpath, encoding, newline)
#     267
#     268     ds = DataSource(destpath)
# --> 269     return ds.open(path, mode, encoding=encoding, newline=newline)
#     270
#     271
#
# ~/anaconda3/envs/jupy/lib/python3.7/site-packages/numpy/lib/_datasource.py in open(self, path, mode, encoding, newline)
#     621                                       encoding=encoding, newline=newline)
#     622         else:
# --> 623             raise IOError("%s not found." % path)
#     624
#     625
#
# OSError: ../../../measurements/FSS_tfs/12_14_2019b/fssmixerout_SR560B_inj700mV_amp.TXT not found.

# %%
amp_extra = np.loadtxt(folder + out_chan   + midix + dial_adj + '_' + inj_set[0] +  suffix[0] + ex_label + '.TXT')
ph_extra = np.loadtxt(folder + out_chan   + midix + dial_adj + '_' + inj_set[0] +  suffix[1] + ex_label + '.TXT')

# %%
amp[0][:,0]
# Out:
# array([1.000000e+00, 1.059686e+00, 1.122935e+00, 1.189959e+00,
#        1.260984e+00, 1.336248e+00, 1.416003e+00, 1.500520e+00,
#        1.590080e+00, 1.684987e+00, 1.785558e+00, 1.892131e+00,
#        2.005066e+00, 2.124741e+00, 2.251559e+00, 2.385947e+00,
#        2.528356e+00, 2.679264e+00, 2.839180e+00, 3.008641e+00,
#        3.188216e+00, 3.378509e+00, 3.580161e+00, 3.793848e+00,
#        4.020289e+00, 4.260246e+00, 4.514525e+00, 4.783981e+00,
#        5.069520e+00, 5.372102e+00, 5.692743e+00, 6.032523e+00,
#        6.392583e+00, 6.774134e+00, 7.178458e+00, 7.606915e+00,
#        8.060945e+00, 8.542073e+00, 9.051920e+00, 9.592196e+00,
#        1.016472e+01, 1.077142e+01, 1.141432e+01, 1.209561e+01,
#        1.281755e+01, 1.358258e+01, 1.439328e+01, 1.525236e+01,
#        1.616272e+01, 1.712742e+01, 1.814969e+01, 1.923299e+01,
#        2.038094e+01, 2.159740e+01, 2.288647e+01, 2.425249e+01,
#        2.570003e+01, 2.723398e+01, 2.885948e+01, 3.058200e+01,
#        3.240733e+01, 3.434161e+01, 3.639133e+01, 3.856340e+01,
#        4.086512e+01, 4.330421e+01, 4.588889e+01, 4.862783e+01,
#        5.153025e+01, 5.460592e+01, 5.786515e+01, 6.131891e+01,
#        6.497882e+01, 6.885718e+01, 7.296702e+01, 7.732217e+01,
#        8.193725e+01, 8.682780e+01, 9.201024e+01, 9.750201e+01,
#        1.033216e+02, 1.094885e+02, 1.160234e+02, 1.229485e+02,
#        1.302868e+02, 1.380632e+02, 1.463037e+02, 1.550360e+02,
#        1.642896e+02, 1.740954e+02, 1.844866e+02, 1.954979e+02,
#        2.071665e+02, 2.195316e+02, 2.326346e+02, 2.465198e+02,
#        2.612336e+02, 2.768258e+02, 2.933485e+02, 3.108575e+02,
#        3.294114e+02, 3.490728e+02, 3.699078e+02, 3.919862e+02,
#        4.153825e+02, 4.401752e+02, 4.664478e+02, 4.942884e+02,
#        5.237906e+02, 5.550539e+02, 5.881831e+02, 6.232897e+02,
#        6.604916e+02, 6.999140e+02, 7.416895e+02, 7.859583e+02,
#        8.328693e+02, 8.825803e+02, 9.352584e+02, 9.910807e+02,
#        1.050235e+03, 1.112920e+03, 1.179346e+03, 1.249737e+03,
#        1.324329e+03, 1.403374e+03, 1.487136e+03, 1.575898e+03,
#        1.669958e+03, 1.769632e+03, 1.875255e+03, 1.987182e+03,
#        2.105790e+03, 2.231477e+03, 2.364666e+03, 2.505805e+03,
#        2.655367e+03, 2.813857e+03, 2.981806e+03, 3.159779e+03,
#        3.348375e+03, 3.548228e+03, 3.760009e+03, 3.984431e+03,
#        4.222248e+03, 4.474258e+03, 4.741311e+03, 5.024303e+03,
#        5.324186e+03, 5.641968e+03, 5.978717e+03, 6.335565e+03,
#        6.713713e+03, 7.114431e+03, 7.539066e+03, 7.989046e+03,
#        8.465885e+03, 8.971183e+03, 9.506642e+03, 1.007406e+04,
#        1.067534e+04, 1.131252e+04, 1.198772e+04, 1.270323e+04,
#        1.346144e+04, 1.426490e+04, 1.511632e+04, 1.601856e+04,
#        1.697466e+04, 1.798781e+04, 1.906144e+04, 2.019915e+04,
#        2.140477e+04, 2.268234e+04, 2.403617e+04, 2.547080e+04,
#        2.699107e+04, 2.860207e+04, 3.030922e+04, 3.211828e+04,
#        3.403530e+04, 3.606675e+04, 3.821945e+04, 4.050063e+04,
#        4.291797e+04, 4.547959e+04, 4.819411e+04, 5.107064e+04,
#        5.411887e+04, 5.734903e+04, 6.077199e+04, 6.439926e+04,
#        6.824302e+04, 7.231620e+04, 7.663251e+04, 8.120643e+04,
#        8.605335e+04, 9.118957e+04, 9.663236e+04, 1.024000e+05])

# %%
fig = plt.figure(figsize=(17,15))
plt.subplot(211)
plt.title('CLTF ' + '[' + out_chan + '/' + in_chan + ']'  ,fontsize=25)
ax = plt.gca()
plt.ylabel('dB',fontsize=20)
plt.grid('True', which='both')
plt.grid('True')
ax.tick_params(which='both', width=1)
ax.tick_params(which='minor', length=2)
ax.tick_params(labelsize=15)
ax.yaxis.offsetText.set_fontsize(15)
for i in range(len(amp)):
    plt.plot(amp[i][:,0],amp[i][:,1],label= inj_set[i])
#plt.plot(amp_extra[:,0],amp_extra[:,1], label= dial_adj + '_' + gain_set[0] + ex_label)
plt.xlim([1,amp[0][-1,0]])
ax.set_xscale('log')
plt.legend(prop={'size':20})
plt.subplot(212)
for i in range(len(ph)):
    plt.plot(ph[i][:,0],ph[i][:,1],label= inj_set[i])
#plt.plot(ph_extra[:,0],ph_extra[:,1], label= dial_adj + '_' + gain_set[0] + ex_label)
ax = plt.gca()
plt.ylabel('phase (degrees)',fontsize=20)
plt.grid('True', which='both')
plt.grid('True')
ax.tick_params(which='both', width=1)
ax.tick_params(which='minor', length=2)
ax.tick_params(labelsize=15)
ax.yaxis.offsetText.set_fontsize(15)
plt.xlabel('frequency [Hz]',fontsize=20)
plt.xlim([1,ph[0][-1,0]])
ax.set_xscale('log')
plt.legend(prop={'size':20}, loc=0)
plt.savefig(folder + 'CLTF_' + out_chan + '_' +  in_chan + '.png',dpi=300,bbox_inches='tight')
