# %%
import numpy as np 
import matplotlib.pyplot as plt
import h5py
dir1 = '/Users/daniel_vander-hyde/Documents/git/SU/algaas_electrooptic_effect/measurements/08_04_2020_null_result/'
dir2 = '/Users/daniel_vander-hyde/Documents/git/SU/algaas_electrooptic_effect/measurements/08_06_2020_0deg_orientation/'
plt.style.use('/Users/daniel_vander-hyde/Documents/git/my_python/matplotlib/stylelib/pptsize')
dat_f1 =  np.loadtxt(dir1 + 'noise_floor' + '.TXT')
dat_drive1 =  np.loadtxt(dir1 + '300Vpk_to_electrodes' + '.TXT')
dat_nodrive1 =  np.loadtxt(dir1 + '300Vpk_electrodes_disconnected' + '.TXT')
ff = dat_f1[:,0]

# %%
dat_f2 =  np.loadtxt(dir2 + 'noise_floor' + '.TXT')
dat_drive2 =  np.loadtxt(dir2 + '300Vpk_to_electrodes' + '.TXT')
dat_nodrive2 =  np.loadtxt(dir2 + '300Vpk_electrodes_disconnected' + '.TXT')

# %%
fig = plt.figure()
plt.loglog(ff,dat_f1[:,1], label='noise')
plt.loglog(ff,dat_nodrive1[:,1], label='300V$_{\mathrm{pk}}$, electrodes disconnected')
plt.loglog(ff,dat_drive1[:,1], label='300V$_{\mathrm{pk}}$ to electrodes')
plt.loglog(ff,dat_f2[:,1], label='noise')
plt.loglog(ff,dat_nodrive2[:,1], label='300V$_{\mathrm{pk}}$, electrodes disconnected')
plt.loglog(ff,dat_drive2[:,1], label='300V$_{\mathrm{pk}}$ to electrodes')
plt.xlim(ff[0], ff[-1])
plt.xlim(ff[0], ff[-1])
plt.ylabel('V$_{\mathrm{pk}}$')
plt.legend()
plt.title('Null result')
# Out:
# Text(0.5, 1.0, 'Null result')

# %%
fig = plt.figure()
plt.loglog(ff,dat_f2[:,1], label='noise')
plt.loglog(ff,dat_nodrive2[:,1], label='300V$_{\mathrm{pk}}$, electrodes disconnected')
plt.loglog(ff,dat_drive2[:,1], label='300V$_{\mathrm{pk}}$ to electrodes')
plt.xlim(ff[0], ff[-1])
plt.ylabel('V$_{\mathrm{pk}}$')
plt.legend()
plt.title('Null result')
# Out:
# Text(0.5, 1.0, 'Null result')
