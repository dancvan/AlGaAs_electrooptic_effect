# %%
import numpy as np 
import matplotlib.pyplot as plt
import pandas as pd
import h5py
import sys
sys.path.append('/Users/daniel_vander-hyde/Documents/git/my_python/grad_plot/')
from grad_plot import grad_plot
from sdc import sdc
folder = '/Users/daniel_vander-hyde/Documents/git/SU/algaas_electrooptic_effect/measurements/FSS_tfs/spice/10_14_2020/'
plt.style.use('/Users/daniel_vander-hyde/Documents/git/my_python/matplotlib/stylelib/pptsize')

# %%
file_prefix = 'ellip'

# %%
sdc.spice2hdf5(folder, file_prefix)

# %%
dat = h5py.File(folder + file_prefix + '.h5', 'r')

# %%
grad_plot.mybode(dat['freq'], dat['dB'],dat['deg'])
plt.savefig(folder + file_prefix + '.png',dpi=150,bbox_inches='tight')

# %%
dat.close()
