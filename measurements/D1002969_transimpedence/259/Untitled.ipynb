# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
data_in = np.genfromtxt('time_inp_259.CSV',delimiter=',')
data_out = np.genfromtxt('time_out_259.CSV',delimiter =',')

# %%
sample_interval =  1/(data_in[:,1][1])
print(sample_interval)
# Out:
# 50000000000.0

# %%
plt.plot(data_in[:,3],data_in[:,4])
plt.plot(data_out[:,3],data_out[:,4])

# %%
20*np.log10(max(data_out[:,4])/max(data_in[:,4]))
# Out:
# 17.00475359333336

# %%
plt.plot(data_out[0:300,3],data_out[0:300,4])

# %%
# Out:
# 1.36
