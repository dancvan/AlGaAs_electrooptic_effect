# %%
# import python packages
import sdfascii as sdf
import matplotlib.pyplot as plt
import numpy as np

# %%
CH1_TP4 = sdf.read_sdf_file('QPD5CH1T.DAT')
CH2_TP4 = sdf.read_sdf_file('QPD5CH2T.DAT')
CH3_TP4 = sdf.read_sdf_file('QPD4CH3T.DAT')
CH4_TP4 = sdf.read_sdf_file('QPD5CH4T.DAT')
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-2-e8982c60c681> in <module>()
# ----> 1 CH1_TP4 = sdf.read_sdf_file('QPD5CH1T.DAT')
#       2 CH2_TP4 = sdf.read_sdf_file('QPD5CH2T.DAT')
#       3 CH3_TP4 = sdf.read_sdf_file('QPD4CH3T.DAT')
#       4 CH4_TP4 = sdf.read_sdf_file('QPD5CH4T.DAT')
#
# /Users/daniel_vander-hyde/miniconda3/envs/ipykernel_py2/lib/python2.7/site-packages/sdfascii.pyc in read_sdf_file(sdf_filename)
#     408     sdf_hdr['channel_hdr'] = []  # There are 0 or more channel header records
#     409
# --> 410     with open(sdf_filename, 'rb') as sdf_file:
#     411         # Read SDF file_identfication
#     412         file_identifier = sdf_file.read(2)
#
# IOError: [Errno 2] No such file or directory: 'QPD5CH1T.DAT'

# %%
len(TP8CH3[1])*32
# Out:
# 51232

# %%
fig = plt.figure(figsize=(20,15))
freq = np.arange(0,len(TP8CH1[1])*32,32)
plt.plot(freq, TP8CH1[1], label='TP8CH1')
plt.plot(freq, TP8CH2[1], label='TP8CH2')
plt.plot(freq, TP8CH3[1], label='TP8CH3')
plt.plot(freq, TP8CH4[1], label='TP8CH4')
plt.xlabel('Frequency (Hz)', FontSize=20)
plt.ylabel('Volts?', FontSize=20)
plt.title('QPD D1600196 dark noise measurement', FontSize=25)
plt.legend(prop={'size' : 15})

# %% [markdown]
# ## Still need to find correct conversion for y data (noise floor estimate) ~ 20 $\mu$V
