# %%
import numpy as np
import matplotlib.pyplot as plt
folder ="../../../../measurements/OLG/"
dir1 = "algaas/05_27_2020/"
dir2 = "1_16_2020/"

# %%
db1 = np.loadtxt(folder + dir1 + 'db.TXT')
deg1 = np.loadtxt(folder + dir1 + 'deg.TXT')
ff1 = db1[:,0]

# %%
db2 = np.loadtxt(folder + dir2 + 'OLG_AMP.TXT')
deg2 = np.loadtxt(folder + dir2 + 'OLG_PH.TXT')
ff2 = db2[:,0]

# %%
plt.style.use('pptsize')
plt.subplot(211)
plt.semilogx(ff1,db1[:,1], label = 'AlGaAs end mirror')
plt.semilogx(ff2,db2[:,1], label = 'SiO2/TaO5 end mirror')
plt.xlim(ff1[0], ff1[-1])
plt.ylabel('dB')
plt.title("OLG")
plt.legend()
plt.subplot(212)
plt.semilogx(ff1,deg1[:,1], label = 'AlGaAs end mirror')
plt.semilogx(ff2,deg2[:,1], label = 'AlGaAs end mirror')
plt.xlim(ff1[0], ff1[-1])
#plt.ylim(1e-4, .4*1e-1)
plt.legend()
plt.xlabel('Frequency [Hz]')
plt.ylabel('phase [deg]')
# Out:
# Text(0, 0.5, 'phase [deg]')

# %%
fig = plt.figure(figsize=(36.8,20))
plt.semilogx(ff,deg[:,1], label = 'AlGaAs end mirror')
plt.xlim(ff[0], ff[-1])
#plt.ylim(1e-4, .4*1e-1)
plt.legend(fontsize=30)
plt.xlabel('Frequency [Hz]',FontSize=30)
plt.ylabel('phase [deg]',FontSize=30)
plt.title("OLG", FontSize=50)
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.grid(b=None, which='both', axis='both',linewidth=2)
ax = plt.axes()
ax.tick_params(axis='both', which='both',length=5,width=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-11f9916cbbe3> in <module>
#       1 fig = plt.figure(figsize=(36.8,20))
# ----> 2 plt.semilogx(ff,deg[:,1], label = 'AlGaAs end mirror')
#       3 plt.xlim(ff[0], ff[-1])
#       4 #plt.ylim(1e-4, .4*1e-1)
#       5 plt.legend(fontsize=30)
#
# NameError: name 'ff' is not defined
