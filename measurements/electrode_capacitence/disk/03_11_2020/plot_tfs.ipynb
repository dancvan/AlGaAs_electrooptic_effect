# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
rc('text', usetex=True)

# %%
amp1 = np.loadtxt('HVA_SVR_dB.TXT')
amp2 = np.loadtxt('HVA_SVR_electrodes_dB.TXT')
amp3 = np.loadtxt('electrode_cap_dB.TXT')

# %%
deg1 = np.loadtxt('HVA_SVR_deg.TXT')
deg2 = np.loadtxt('HVA_SVR_electrodes_deg.TXT')
deg3= np.loadtxt( 'electrode_cap_deg.TXT')

# %%
fig = plt.figure(figsize=(30,20))
plt.subplot(211)
ax.tick_params(axis='both', which='both',length=5,width=2)
ax = plt.gca()
plt.grid(b=None, which='both', axis='both',linewidth=2)
plt.axvline(60000, color='red')
plt.axhline(-.090, color='red')
plt.ylabel('dB',FontSize=30)
plt.title("LPF with 10k$\Omega$ resistor and electrodes (with 1in fused silica dielectric with HR amorphous coating)", FontSize=50)
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.xlim([amp3[0,0], amp3[-1,0]])
plt.semilogx(amp3[:,0],amp3[:,1])
plt.subplot(212)
ax = plt.gca()
ax.tick_params(axis='both', which='both',length=5,width=2)
plt.semilogx(deg3[:,0],deg3[:,1])
plt.axvline(60000, color='red')
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.xlim([amp3[0,0], amp3[-1,0]])
plt.grid(b=None, which='both', axis='both',linewidth=2)
plt.ylabel('phase [deg]',FontSize=30)
plt.xlabel('Frequency [Hz]',FontSize=30)
plt.savefig('LPF_electrodes.png',dpi=300,bbox_inches='tight')

# %%
fig = plt.figure(figsize=(30,20))
plt.subplot(211)
plt.semilogx(amp1[:,0],amp1[:,1])
ax = plt.gca()
ax.tick_params(axis='both', which='both',length=5,width=2)
plt.axhline(29.8, color='red')
plt.axhline(26.8, color='red')
plt.xlim([amp1[0,0], amp1[-1,0]])
plt.axvline(63500, color='red')
plt.ylabel('dB',FontSize=30)
plt.title("HVA (SVR-350 bip) without electrodes", FontSize=50)
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.grid(b=None, which='both', axis='both',linewidth=2)
plt.subplot(212)
ax = plt.gca()
ax.tick_params(axis='both', which='both',length=5,width=2)
plt.semilogx(deg1[:,0],deg1[:,1])
plt.axvline(60000, color='red')
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.xlim([amp3[0,0], amp3[-1,0]])
plt.grid(b=None, which='both', axis='both',linewidth=2)
plt.ylabel('phase [deg]',FontSize=30)
plt.xlabel('Frequency [Hz]',FontSize=30)
plt.savefig('HVA_SVR.png',dpi=300,bbox_inches='tight')

# %%
fig = plt.figure(figsize=(30,20))
plt.subplot(211)
plt.semilogx(amp2[:,0],amp2[:,1])
ax = plt.gca()
ax.tick_params(axis='both', which='both',length=5,width=2)
plt.xlim([amp2[0,0], amp2[-1,0]])
plt.axvline(50000, color='red')
plt.axhline(29.7, color='red')
plt.axhline(26.7, color='red')
plt.ylabel('dB',FontSize=30)
plt.title("HVA (SVR-350 bip) with electrodes", FontSize=50)
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.grid(b=None, which='both', axis='both',linewidth=2)
plt.subplot(212)
plt.semilogx(deg2[:,0],deg2[:,1])
ax = plt.gca()
ax.tick_params(axis='both', which='both',length=5,width=2)
plt.xlim([deg2[0,0], deg2[-1,0]])
plt.axvline(50000, color='red')
plt.xlabel('Frequency [Hz]',FontSize=30)
plt.ylabel('phase [deg]',FontSize=30)
plt.xticks(fontsize=30, rotation=0)
plt.yticks(fontsize=30, rotation=0)
plt.grid(b=None, which='both', axis='both',linewidth=2)
plt.savefig('HVA_SVR_with_electrodes.png',dpi=300,bbox_inches='tight')
